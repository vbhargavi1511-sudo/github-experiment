# %%
t=6,8,9
type(t)
# Out:
# tuple

# %%
s={}
type(s)
# Out:
# dict

# %%
l=[9,0,67,0,8,8]
#how to remove the duplicate element
set(l)
# Out:
# {0, 8, 9, 67}

# %%
s={89,90,6,'p',788888,4556,9,(8,8)}
s
# Out:
# {(8, 8), 4556, 6, 788888, 89, 9, 90, 'p'}

# %%
s={89,90,6,'p',788888,4556,9}
s[0]=9
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 s={89,90,6,'p',788888,4556,9}
# ----> 2 s[0]=9
#
# TypeError: 'set' object does not support item assignment

# %%
s={9,9,0}#add will add 1 element
s.add(7)
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}#update will add multiple values
s.update([7,0,9])
s
# Out:
# {0, 7, 9}

# %%
s={9,9,0}#update will add multiple values
s.add([7,0,9])#add cannot add multiple values using list
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 s={9,9,0}#update will add multiple values
# ----> 2 s.add([7,0,9])
#       3 s
#
# TypeError: unhashable type: 'list'

# %%
s={9,9,0}#update will add multiple values
s.add((7,0,9))#add cannot add multiple values using list,using tuple we can add
s
# Out:
# {(7, 0, 9), 0, 9}

# %%
#i want to delete element
s={5,8,9}#if element is not there it willl give error
s.remove(9)
s
# Out:
# {5, 8}

# %%
s={5,8,9}# if element is not there it will not give error
s.discard(8)
s
# Out:
# {5, 9}

# %%
s={7,90,60}
s.pop()
# Out:
# 90

# %%
l=[7,9,80,98]#list is order
l.pop()
# Out:
# 98

# %%
l=[7,9,80,98]#list is order
l.pop(2)
# Out:
# 80
